# %%
# %run student_results_analysis.py
# Out:
# C:\Users\Vu Anh Vinh\Miniconda3\envs\thkstat\lib\site-packages\IPython\html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)
# Grid search for... support vector regression
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV] C=0.001, kernel=linear ..........................................
# [CV] .......... C=0.001, kernel=linear, score=-0.095424, total=   0.0s
# [CV] C=0.001, kernel=linear ..........................................
# [CV] .......... C=0.001, kernel=linear, score=-0.167192, total=   0.0s
# [CV] C=0.001, kernel=linear ..........................................
# ...

# %%
# %run student_results_analysis.py
# Out:
# Grid search for... support vector regression
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV] C=0.001, kernel=linear ..........................................
# [CV] .......... C=0.001, kernel=linear, score=-0.056637, total=   0.0s
# [CV] C=0.001, kernel=linear ..........................................
# [CV] ........... C=0.001, kernel=linear, score=0.003328, total=   0.0s
# [CV] C=0.001, kernel=linear ..........................................
# [CV] .......... C=0.001, kernel=linear, score=-0.057018, total=   0.0s
# [CV] C=0.001, kernel=linear ..........................................
# [CV] .......... C=0.001, kernel=linear, score=-0.048648, total=   0.0s
# [CV] C=0.001, kernel=linear ..........................................
# [CV] ........... C=0.001, kernel=linear, score=0.003082, total=   0.0s
# ...

# %%
# %run student_results_analysis.py
# Out:
# Grid search for... support vector regression
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV] C=0.001, kernel=linear ..........................................
# [CV] .......... C=0.001, kernel=linear, score=-0.070328, total=   0.0s
# [CV] C=0.001, kernel=linear ..........................................
# [CV] .......... C=0.001, kernel=linear, score=-0.005540, total=   0.0s
# [CV] C=0.001, kernel=linear ..........................................
# [CV] .......... C=0.001, kernel=linear, score=-0.070485, total=   0.0s
# [CV] C=0.001, kernel=linear ..........................................
# [CV] .......... C=0.001, kernel=linear, score=-0.062582, total=   0.0s
# [CV] C=0.001, kernel=linear ..........................................
# [CV] .......... C=0.001, kernel=linear, score=-0.008391, total=   0.0s
# ...
