# %%
import pandas as pd
xl = pd.ExcelFile("Big Data.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-05db2d041468> in <module>()
#       1 import pandas as pd
# ----> 2 xl = pd.ExcelFile("Big Data.xlsx")
#
# C:\Users\Vu Anh Vinh\Miniconda3\envs\thkstat\lib\site-packages\pandas\io\excel.py in __init__(self, io, **kwds)
#     196     def __init__(self, io, **kwds):
#     197
# --> 198         import xlrd  # throw an ImportError if we need to
#     199
#     200         ver = tuple(map(int, xlrd.__VERSION__.split(".")[:2]))
#
# ImportError: No module named 'xlrd'

# %%
xl = pd.ExcelFile("Student Results.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-c8f139b4a135> in <module>()
# ----> 1 xl = pd.ExcelFile("Student Results.xlsx")
#
# C:\Users\Vu Anh Vinh\Miniconda3\envs\thkstat\lib\site-packages\pandas\io\excel.py in __init__(self, io, **kwds)
#     196     def __init__(self, io, **kwds):
#     197
# --> 198         import xlrd  # throw an ImportError if we need to
#     199
#     200         ver = tuple(map(int, xlrd.__VERSION__.split(".")[:2]))
#
# ImportError: No module named 'xlrd'

# %%
rs = pd.read_csv("Student Results.csv")

# %%
rs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 19 columns):
# S/No           92 non-null int64
# Year           92 non-null int64
# Nationality    92 non-null object
# CA1            92 non-null object
# CA2-1          92 non-null object
# CA2-2          92 non-null object
# CA2 Total      92 non-null object
# CA3-1          91 non-null float64
# CA3-2          91 non-null float64
# CA3-3          91 non-null float64
# CA3 Total      92 non-null object
# CA4            92 non-null object
# CA Total       92 non-null object
# Exam Q1        92 non-null object
# Exam Q2        92 non-null object
# Exam Q3        92 non-null object
# Exam Q4        92 non-null object
# Exam Total     92 non-null object
# Final Total    92 non-null object
# dtypes: float64(3), int64(2), object(14)
# memory usage: 13.7+ KB

# %%
rs.head()
# Out:
#    S/No  Year Nationality  CA1 CA2-1 CA2-2 CA2 Total  CA3-1  CA3-2  CA3-3  \
# 0     1     2       CONT5  100    30     5        35    6.0   28.0   17.0
# 1     2     3       CONT1  100    24     2        26    6.0   28.0    5.0
# 2     3     2       CONT3  100    36    10        46    9.0   30.0   13.0
# 3     4     1       CONT2  100    30     4        34    4.0    6.0    2.0
# 4     5     3       CONT3  100    33     8        41    6.0   22.0   14.0
#
#   CA3 Total CA4 CA Total Exam Q1 Exam Q2 Exam Q3 Exam Q4 Exam Total  \
# 0        57  78    78.83      10      14      18      12         54
# 1        45  70    65.89       8      12      13       5         38
# 2        61  60    81.74      15      18      18      18         69
# 3        16  62    58.86       7       9       6       6         28
# 4        48  65    74.67       7      13      18      11         49
#
#   Final Total
# 0       63.93
# 1       49.15
# 2        74.1
# 3       40.34
# 4       59.27

# %%
rs[rs.notnull()]
# Out:
#     S/No  Year Nationality  CA1 CA2-1 CA2-2 CA2 Total  CA3-1  CA3-2  CA3-3  \
# 0      1     2       CONT5  100    30     5        35    6.0   28.0   17.0
# 1      2     3       CONT1  100    24     2        26    6.0   28.0    5.0
# 2      3     2       CONT3  100    36    10        46    9.0   30.0   13.0
# 3      4     1       CONT2  100    30     4        34    4.0    6.0    2.0
# 4      5     3       CONT3  100    33     8        41    6.0   22.0   14.0
# 5      6     1       CONT5  100    34     9        43    7.0   30.0   17.0
# 6      7     2       CONT1  100    32     6        38    5.0   24.0   10.0
# 7      8     1       CONT3  100    40    10        50    7.0   30.0   20.0
# 8      9     1       CONT3  100    39     8        47   10.0   29.0   20.0
# 9     10     1       CONT3   97    40     8        48    9.0   30.0   15.0
# 10    11     1       CONT3  100    32    10        42    8.0   26.0   19.0
# ...

# %%
clean = rs.dropna()

# %%
clean
# Out:
#     S/No  Year Nationality  CA1 CA2-1 CA2-2 CA2 Total  CA3-1  CA3-2  CA3-3  \
# 0      1     2       CONT5  100    30     5        35    6.0   28.0   17.0
# 1      2     3       CONT1  100    24     2        26    6.0   28.0    5.0
# 2      3     2       CONT3  100    36    10        46    9.0   30.0   13.0
# 3      4     1       CONT2  100    30     4        34    4.0    6.0    2.0
# 4      5     3       CONT3  100    33     8        41    6.0   22.0   14.0
# 5      6     1       CONT5  100    34     9        43    7.0   30.0   17.0
# 6      7     2       CONT1  100    32     6        38    5.0   24.0   10.0
# 7      8     1       CONT3  100    40    10        50    7.0   30.0   20.0
# 8      9     1       CONT3  100    39     8        47   10.0   29.0   20.0
# 9     10     1       CONT3   97    40     8        48    9.0   30.0   15.0
# 10    11     1       CONT3  100    32    10        42    8.0   26.0   19.0
# ...

# %%
clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91 entries, 0 to 91
# Data columns (total 19 columns):
# S/No           91 non-null int64
# Year           91 non-null int64
# Nationality    91 non-null object
# CA1            91 non-null object
# CA2-1          91 non-null object
# CA2-2          91 non-null object
# CA2 Total      91 non-null object
# CA3-1          91 non-null float64
# CA3-2          91 non-null float64
# CA3-3          91 non-null float64
# CA3 Total      91 non-null object
# CA4            91 non-null object
# CA Total       91 non-null object
# Exam Q1        91 non-null object
# Exam Q2        91 non-null object
# Exam Q3        91 non-null object
# Exam Q4        91 non-null object
# Exam Total     91 non-null object
# Final Total    91 non-null object
# dtypes: float64(3), int64(2), object(14)
# memory usage: 14.2+ KB

# %%
clean.ix[54]
# Out:
# S/No              55
# Year               2
# Nationality    CONT1
# CA1              100
# CA2-1             20
# CA2-2              5
# CA2 Total         25
# CA3-1              6
# CA3-2             13
# CA3-3              9
# CA3 Total         34
# CA4               65
# CA Total       59.07
# Exam Q1            7
# Exam Q2           10
# Exam Q3           10
# Exam Q4            5
# Exam Total        32
# Final Total    42.83
# Name: 54, dtype: object

# %%
clean.describe()
# Out:
#             S/No       Year      CA3-1      CA3-2      CA3-3
# count  91.000000  91.000000  91.000000  91.000000  91.000000
# mean   46.417582   1.439560   7.153846  24.879121  12.857143
# std    26.838226   0.541783   2.102502   6.739329   4.909337
# min     1.000000   1.000000   0.000000   2.000000   0.000000
# 25%    23.500000   1.000000   6.000000  23.000000   9.000000
# 50%    46.000000   1.000000   7.000000  28.000000  14.000000
# 75%    69.500000   2.000000   9.000000  30.000000  17.000000
# max    92.000000   3.000000  10.000000  30.000000  20.000000

# %%
clean[clean['CA1'] < 100]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-af223a082fba> in <module>()
# ----> 1 clean[clean['CA1'] < 100]
#
# C:\Users\Vu Anh Vinh\Miniconda3\envs\thkstat\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#     761                 other = np.asarray(other)
#     762
# --> 763             res = na_op(values, other)
#     764             if isscalar(res):
#     765                 raise TypeError('Could not compare %s type with Series' %
#
# C:\Users\Vu Anh Vinh\Miniconda3\envs\thkstat\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     681                     result = lib.vec_compare(x, y, op)
#     682             else:
# --> 683                 result = lib.scalar_compare(x, y, op)
#     684         else:
#     685
#
# pandas\lib.pyx in pandas.lib.scalar_compare (pandas\lib.c:14261)()
#
# ...

# %%
clean['CA1'] = clean['CA1'].astype(int)
# Out:
# C:\Users\Vu Anh Vinh\Miniconda3\envs\thkstat\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
clean.describe()
# Out:
#             S/No       Year         CA1      CA3-1      CA3-2      CA3-3
# count  91.000000  91.000000   91.000000  91.000000  91.000000  91.000000
# mean   46.417582   1.439560   98.153846   7.153846  24.879121  12.857143
# std    26.838226   0.541783    9.547452   2.102502   6.739329   4.909337
# min     1.000000   1.000000   22.000000   0.000000   2.000000   0.000000
# 25%    23.500000   1.000000  100.000000   6.000000  23.000000   9.000000
# 50%    46.000000   1.000000  100.000000   7.000000  28.000000  14.000000
# 75%    69.500000   2.000000  100.000000   9.000000  30.000000  17.000000
# max    92.000000   3.000000  100.000000  10.000000  30.000000  20.000000

# %%
clean.columns
# Out:
# Index(['S/No', 'Year', 'Nationality', 'CA1', 'CA2-1', 'CA2-2', 'CA2 Total',
#        'CA3-1', 'CA3-2', 'CA3-3', 'CA3 Total', 'CA4', 'CA Total', 'Exam Q1',
#        'Exam Q2', 'Exam Q3', 'Exam Q4', 'Exam Total', 'Final Total'],
#       dtype='object')

# %%
clean.ix[:,3:7] = clean.ix[:,3:7].astype(int)
# Out:
# C:\Users\Vu Anh Vinh\Miniconda3\envs\thkstat\lib\site-packages\pandas\core\indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
clean.describe()
# Out:
#             S/No       Year         CA1      CA2-1      CA2-2  CA2 Total  \
# count  91.000000  91.000000   91.000000  91.000000  91.000000  91.000000
# mean   46.417582   1.439560   98.153846  31.340659   7.340659  38.681319
# std    26.838226   0.541783    9.547452   4.612109   2.181843   6.183992
# min     1.000000   1.000000   22.000000  19.000000   2.000000  23.000000
# 25%    23.500000   1.000000  100.000000  29.000000   6.000000  35.000000
# 50%    46.000000   1.000000  100.000000  32.000000   7.000000  39.000000
# 75%    69.500000   2.000000  100.000000  34.000000   9.500000  43.000000
# max    92.000000   3.000000  100.000000  40.000000  10.000000  50.000000
#
#            CA3-1      CA3-2      CA3-3
# count  91.000000  91.000000  91.000000
# mean    7.153846  24.879121  12.857143
# std     2.102502   6.739329   4.909337
# min     0.000000   2.000000   0.000000
# 25%     6.000000  23.000000   9.000000
# 50%     7.000000  28.000000  14.000000
# ...

# %%
clean.describe().type()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-ae932883dfff> in <module>()
# ----> 1 clean.describe().type()
#
# C:\Users\Vu Anh Vinh\Miniconda3\envs\thkstat\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'type'

# %%
clean.ix[:,10:19] = clean.ix[:,10:19].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-0cf335a973c4> in <module>()
# ----> 1 clean.ix[:,10:19] = clean.ix[:,10:19].astype(int)
#
# C:\Users\Vu Anh Vinh\Miniconda3\envs\thkstat\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, raise_on_error, **kwargs)
#    2948
#    2949         mgr = self._data.astype(dtype=dtype, copy=copy,
# -> 2950                                 raise_on_error=raise_on_error, **kwargs)
#    2951         return self._constructor(mgr).__finalize__(self)
#    2952
#
# C:\Users\Vu Anh Vinh\Miniconda3\envs\thkstat\lib\site-packages\pandas\core\internals.py in astype(self, dtype, **kwargs)
#    2936
#    2937     def astype(self, dtype, **kwargs):
# -> 2938         return self.apply('astype', dtype=dtype, **kwargs)
#    2939
#    2940     def convert(self, **kwargs):
#
# ...

# %%
clean.ix[:,10:19] = clean.ix[:,10:19].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-8e6cd85c6639> in <module>()
# ----> 1 clean.ix[:,10:19] = clean.ix[:,10:19].astype(float)
#
# C:\Users\Vu Anh Vinh\Miniconda3\envs\thkstat\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, raise_on_error, **kwargs)
#    2948
#    2949         mgr = self._data.astype(dtype=dtype, copy=copy,
# -> 2950                                 raise_on_error=raise_on_error, **kwargs)
#    2951         return self._constructor(mgr).__finalize__(self)
#    2952
#
# C:\Users\Vu Anh Vinh\Miniconda3\envs\thkstat\lib\site-packages\pandas\core\internals.py in astype(self, dtype, **kwargs)
#    2936
#    2937     def astype(self, dtype, **kwargs):
# -> 2938         return self.apply('astype', dtype=dtype, **kwargs)
#    2939
#    2940     def convert(self, **kwargs):
#
# ...

# %%
clean = clean[clean['Final Total'] == 'ABS']

# %%
clean.ix[:,10:19] = clean.ix[:,10:19].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-8e6cd85c6639> in <module>()
# ----> 1 clean.ix[:,10:19] = clean.ix[:,10:19].astype(float)
#
# C:\Users\Vu Anh Vinh\Miniconda3\envs\thkstat\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, raise_on_error, **kwargs)
#    2948
#    2949         mgr = self._data.astype(dtype=dtype, copy=copy,
# -> 2950                                 raise_on_error=raise_on_error, **kwargs)
#    2951         return self._constructor(mgr).__finalize__(self)
#    2952
#
# C:\Users\Vu Anh Vinh\Miniconda3\envs\thkstat\lib\site-packages\pandas\core\internals.py in astype(self, dtype, **kwargs)
#    2936
#    2937     def astype(self, dtype, **kwargs):
# -> 2938         return self.apply('astype', dtype=dtype, **kwargs)
#    2939
#    2940     def convert(self, **kwargs):
#
# ...

# %%
clean = rs.dropna()

# %%
clean = clean[clean['Final Total'] != 'ABS']

# %%
clean.ix[:,3:7] = clean.ix[:,3:7].astype(int)
clean.ix[:,10:19] = clean.ix[:,10:19].astype(float)

# %%
clean.describe()
# Out:
#             S/No       Year         CA1      CA2-1      CA2-2  CA2 Total  \
# count  89.000000  89.000000   89.000000  89.000000  89.000000  89.000000
# mean   46.550562   1.449438   99.224719  31.505618   7.415730  38.921348
# std    26.913587   0.543792    4.689817   4.528003   2.141627   6.036301
# min     1.000000   1.000000   61.000000  19.000000   2.000000  23.000000
# 25%    24.000000   1.000000  100.000000  29.000000   6.000000  35.000000
# 50%    46.000000   1.000000  100.000000  32.000000   7.000000  39.000000
# 75%    70.000000   2.000000  100.000000  34.000000  10.000000  43.000000
# max    92.000000   3.000000  100.000000  40.000000  10.000000  50.000000
#
#            CA3-1      CA3-2      CA3-3  CA3 Total        CA4   CA Total  \
# count  89.000000  89.000000  89.000000  89.000000  89.000000  89.000000
# mean    7.247191  25.303371  13.146067  52.943820  71.269663  77.404382
# std     2.029783   6.176209   4.561575  12.336531   8.729214   9.470595
# ...

# %%
meta_data = {'Max': [100,40,10,50,20,30,20,70,100,100,25,25,25,25,100,100],
                'Weightage': [4,9.6,2.4,12,3.4,5.2,3.4,12,12,40,15,15,15,15,60,100.00]}

# %%
frame = pd.DataFrame(meta_data,columns = ['Max','Weightage'],index = list(clean.columns.values)[3:])

# %%
frame
# Out:
#              Max  Weightage
# CA1          100        4.0
# CA2-1         40        9.6
# CA2-2         10        2.4
# CA2 Total     50       12.0
# CA3-1         20        3.4
# CA3-2         30        5.2
# CA3-3         20        3.4
# CA3 Total     70       12.0
# CA4          100       12.0
# CA Total     100       40.0
# Exam Q1       25       15.0
# Exam Q2       25       15.0
# Exam Q3       25       15.0
# Exam Q4       25       15.0
# Exam Total   100       60.0
# Final Total  100      100.0

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sb
# Out:
# C:\Users\Vu Anh Vinh\Miniconda3\envs\thkstat\lib\site-packages\IPython\html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
sb.pairplot(clean, hue='class')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\Vu Anh Vinh\Miniconda3\envs\thkstat\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4154)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4018)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12368)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12322)()
#
# KeyError: 'class'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-7b488bae8fb8> in <module>()
# ...

# %%
def is_outlier(points, thresh=3.5):
    """
    Returns a boolean array with True if points are outliers and False 
    otherwise.

    Parameters:
    -----------
        points : An numobservations by numdimensions array of observations
        thresh : The modified z-score to use as a threshold. Observations with
            a modified z-score (based on the median absolute deviation) greater
            than this value will be classified as outliers.

    Returns:
    --------
        mask : A numobservations-length boolean array.

    References:
    ----------
        Boris Iglewicz and David Hoaglin (1993), "Volume 16: How to Detect and
        Handle Outliers", The ASQC Basic References in Quality Control:
        Statistical Techniques, Edward F. Mykytka, Ph.D., Editor. 
    """
    if len(points.shape) == 1:
        points = points[:,None]
    median = np.median(points, axis=0)
    diff = np.sum((points - median)**2, axis=-1)
    diff = np.sqrt(diff)
    med_abs_deviation = np.median(diff)

    modified_z_score = 0.6745 * diff / med_abs_deviation

    return modified_z_score > thresh

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def main():
    plot(clean.ix[:,3])

    plt.show()

def mad_based_outlier(points, thresh=3.5):
    if len(points.shape) == 1:
        points = points[:,None]
    median = np.median(points, axis=0)
    diff = np.sum((points - median)**2, axis=-1)
    diff = np.sqrt(diff)
    med_abs_deviation = np.median(diff)

    modified_z_score = 0.6745 * diff / med_abs_deviation

    return modified_z_score > thresh

def percentile_based_outlier(data, threshold=95):
    diff = (100 - threshold) / 2.0
    minval, maxval = np.percentile(data, [diff, 100 - diff])
    return (data < minval) | (data > maxval)

def plot(x):
    fig, axes = plt.subplots(nrows=2)
    for ax, func in zip(axes, [percentile_based_outlier, mad_based_outlier]):
        sns.distplot(x, ax=ax, rug=True, hist=False)
        outliers = x[func(x)]
        ax.plot(outliers, np.zeros_like(outliers), 'ro', clip_on=False)

    kwargs = dict(y=0.95, x=0.05, ha='left', va='top')
    axes[0].set_title('Percentile-based Outliers', **kwargs)
    axes[1].set_title('MAD-based Outliers', **kwargs)
    fig.suptitle('Comparing Outlier Tests with n={}'.format(len(x)), size=14)

main()
# Out:
# C:\Users\Vu Anh Vinh\Miniconda3\envs\thkstat\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
mad_based_outlier(clean.ix[:,3], thresh=3.5)
# Out:
# array([False, False, False, False, False, False, False, False, False,
#         True, False, False, False, False, False, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False,  True, False,
#        False, False, False, False, False, False, False,  True], dtype=bool)

# %%
outliners = mad_based_outlier(clean.ix[:,3], thresh=3.5)

# %%
outliners[outliners == True]
# Out:
# array([ True,  True,  True,  True,  True], dtype=bool)

# %%
outliners[outliners == True].index
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-b9dd8076d117> in <module>()
# ----> 1 outliners[outliners == True].index
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'

# %%
percentile_based_outlier(clean.ix[:,3])
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 18     True
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
#       ...
# 61    False
# 63    False
# 64    False
# 65    False
# 66    False
# 67    False
# 68    False
# 69    False
# 70    False
# 71    False
# 72    False
# 73    False
# 74    False
# 75    False
# 76    False
# 77    False
# 78    False
# 79    False
# 80    False
# 81    False
# 82     True
# 83    False
# 84    False
# 85    False
# 86    False
# 87    False
# 88    False
# 89    False
# 90    False
# 91    False
# Name: CA1, dtype: bool

# %%
mad_based_outlier(clean.ix[:,'CA1'], thresh=3.5)
# Out:
# array([False, False, False, False, False, False, False, False, False,
#         True, False, False, False, False, False, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False,  True, False,
#        False, False, False, False, False, False, False,  True], dtype=bool)

# %%
# %run student_results_analysis

# %%
outliers_ca1
# Out:
# []

# %%
outliers_bool
# Out:
# array([False, False, False, False, False, False, False, False, False,
#         True, False, False, False, False, False, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False,  True, False,
#        False, False, False, False, False, False, False,  True], dtype=bool)

# %%
# %run student_results_analysis

# %%
outliers_ca1
# Out:
# []

# %%
# %run student_results_analysis
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\Vu Anh Vinh\Miniconda3\envs\thkstat\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4154)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4018)()
#
# pandas\hashtable.pyx in pandas.hashtable.Int64HashTable.get_item (pandas\hashtable.c:6610)()
#
# pandas\hashtable.pyx in pandas.hashtable.Int64HashTable.get_item (pandas\hashtable.c:6554)()
#
# KeyError: 17
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# %run student_results_analysis
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\Vu Anh Vinh\Miniconda3\envs\thkstat\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4154)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4018)()
#
# pandas\hashtable.pyx in pandas.hashtable.Int64HashTable.get_item (pandas\hashtable.c:6610)()
#
# pandas\hashtable.pyx in pandas.hashtable.Int64HashTable.get_item (pandas\hashtable.c:6554)()
#
# KeyError: 17
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# %run student_results_analysis
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\Vu Anh Vinh\Miniconda3\envs\thkstat\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4154)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4018)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12368)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12322)()
#
# KeyError: 9
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# %run student_results_analysis
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\Vu Anh Vinh\Miniconda3\envs\thkstat\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4154)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4018)()
#
# pandas\hashtable.pyx in pandas.hashtable.Int64HashTable.get_item (pandas\hashtable.c:6610)()
#
# pandas\hashtable.pyx in pandas.hashtable.Int64HashTable.get_item (pandas\hashtable.c:6554)()
#
# KeyError: 17
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# %run student_results_analysis
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\Vu Anh Vinh\Miniconda3\envs\thkstat\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4154)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4018)()
#
# pandas\hashtable.pyx in pandas.hashtable.Int64HashTable.get_item (pandas\hashtable.c:6610)()
#
# pandas\hashtable.pyx in pandas.hashtable.Int64HashTable.get_item (pandas\hashtable.c:6554)()
#
# KeyError: 17
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
result.ix[3,:]
# Out:
# S/No               4
# Year               1
# Nationality    CONT2
# CA1              100
# CA2-1             30
# CA2-2              4
# CA2 Total         34
# CA3-1              4
# CA3-2              6
# CA3-3              2
# CA3 Total         16
# CA4               62
# CA Total       58.86
# Exam Q1            7
# Exam Q2            9
# Exam Q3            6
# Exam Q4            6
# Exam Total        28
# Final Total    40.34
# Name: 3, dtype: object

# %%
type(result.ix[3,:])
# Out:
# pandas.core.series.Series

# %%
# %run student_results_analysis

# %%
outliers_ca1
# Out:
# [9, 17, 41, 79, 88]

# %%
result.count()
# Out:
# S/No           89
# Year           89
# Nationality    89
# CA1            89
# CA2-1          89
# CA2-2          89
# CA2 Total      89
# CA3-1          89
# CA3-2          89
# CA3-3          89
# CA3 Total      89
# CA4            89
# CA Total       89
# Exam Q1        89
# Exam Q2        89
# Exam Q3        89
# Exam Q4        89
# Exam Total     89
# Final Total    89
# dtype: int64

# %%
type(result.count())
# Out:
# pandas.core.series.Series

# %%
result.size()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-3b7d9eb11969> in <module>()
# ----> 1 result.size()
#
# TypeError: 'numpy.int32' object is not callable

# %%
# %run student_results_analysis
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\Vu Anh Vinh\FYP\student_results_analysis.py in <module>()
#      74
#      75 # find outliers for each assignment
# ---> 76 outliers_ca1_index = [i for i in range(len(result['CA1'].count())) if mad_based_outlier(result.ix[:, 'CA1'])==True]
#      77
#      78 mad_based_outlier(result.ix[:, 'CA2 Total'])
#
# TypeError: object of type 'numpy.int32' has no len()

# %%
# %run student_results_analysis
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\Vu Anh Vinh\FYP\student_results_analysis.py in <module>()
#      74
#      75 # find outliers for each assignment
# ---> 76 outliers_ca1_index = [i for i in range(len(result['CA1'])) if mad_based_outlier(result.ix[:, 'CA1'])==True]
#      77
#      78 mad_based_outlier(result.ix[:, 'CA2 Total'])
#
# C:\Users\Vu Anh Vinh\FYP\student_results_analysis.py in <listcomp>(.0)
#      74
#      75 # find outliers for each assignment
# ---> 76 outliers_ca1_index = [i for i in range(len(result['CA1'])) if mad_based_outlier(result.ix[:, 'CA1'])==True]
#      77
#      78 mad_based_outlier(result.ix[:, 'CA2 Total'])
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
# %run student_results_analysis
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\Vu Anh Vinh\FYP\student_results_analysis.py in <module>()
#      74
#      75 # find outliers for each assignment
# ---> 76 outliers_ca1_index = [i for i in range(len(result.ix[:, 'CA1'])) if mad_based_outlier(result.ix[:, 'CA1'])==True]
#      77
#      78 mad_based_outlier(result.ix[:, 'CA2 Total'])
#
# C:\Users\Vu Anh Vinh\FYP\student_results_analysis.py in <listcomp>(.0)
#      74
#      75 # find outliers for each assignment
# ---> 76 outliers_ca1_index = [i for i in range(len(result.ix[:, 'CA1'])) if mad_based_outlier(result.ix[:, 'CA1'])==True]
#      77
#      78 mad_based_outlier(result.ix[:, 'CA2 Total'])
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
# %run student_results_analysis

# %%
outliers_ca1_index
# Out:
# [9, 17, 41, 79, 88]

# %%
result[outliers_ca1_index]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-63-4517e5d24596> in <module>()
# ----> 1 result[outliers_ca1_index]
#
# C:\Users\Vu Anh Vinh\Miniconda3\envs\thkstat\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1989         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1990             # either boolean or fancy integer index
# -> 1991             return self._getitem_array(key)
#    1992         elif isinstance(key, DataFrame):
#    1993             return self._getitem_frame(key)
#
# C:\Users\Vu Anh Vinh\Miniconda3\envs\thkstat\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2034         else:
#    2035             indexer = self.ix._convert_to_indexer(key, axis=1)
# -> 2036             return self.take(indexer, axis=1, convert=True)
#    2037
#    2038     def _getitem_multilevel(self, key):
#
# ...

# %%
result.ix[outliers_ca1_index]
# Out:
#     S/No  Year Nationality    CA1  CA2-1  CA2-2  CA2 Total  CA3-1  CA3-2  \
# 9   10.0   1.0       CONT3   97.0   40.0    8.0       48.0    9.0   30.0
# 17   NaN   NaN         NaN    NaN    NaN    NaN        NaN    NaN    NaN
# 41  42.0   2.0       CONT1  100.0   37.0   10.0       47.0   10.0   30.0
# 79  80.0   1.0       CONT1  100.0   33.0    9.0       42.0   10.0   30.0
# 88  89.0   1.0       CONT1  100.0   24.0    4.0       28.0    6.0    6.0
#
#     CA3-3  CA3 Total   CA4  CA Total  Exam Q1  Exam Q2  Exam Q3  Exam Q4  \
# 9    15.0       63.0  80.0      89.5     15.0     17.0     22.0     13.0
# 17    NaN        NaN   NaN       NaN      NaN      NaN      NaN      NaN
# 41   20.0       70.0  85.0      93.7     15.0     22.0     19.0     10.0
# 79   20.0       70.0  75.0      87.7     23.0     23.0     24.0     20.0
# 88    5.0       23.0  60.0      56.8      5.0     12.0     12.0      4.0
#
#     Exam Total  Final Total
# 9         67.0        76.00
# 17         NaN          NaN
# ...

# %%
outliers_bool_ca1
# Out:
# array([False, False, False, False, False, False, False, False, False,
#         True, False, False, False, False, False, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False,  True, False,
#        False, False, False, False, False, False, False,  True], dtype=bool)

# %%
# %run student_results_analysis

# %%
outliers_ca1_index
# Out:
# [9, 17, 41, 79, 88]

# %%
result.ix[outliers_ca1_index]
# Out:
#     S/No  Year Nationality    CA1  CA2-1  CA2-2  CA2 Total  CA3-1  CA3-2  \
# 9   10.0   1.0       CONT3   97.0   40.0    8.0       48.0    9.0   30.0
# 17   NaN   NaN         NaN    NaN    NaN    NaN        NaN    NaN    NaN
# 41  42.0   2.0       CONT1  100.0   37.0   10.0       47.0   10.0   30.0
# 79  80.0   1.0       CONT1  100.0   33.0    9.0       42.0   10.0   30.0
# 88  89.0   1.0       CONT1  100.0   24.0    4.0       28.0    6.0    6.0
#
#     CA3-3  CA3 Total   CA4  CA Total  Exam Q1  Exam Q2  Exam Q3  Exam Q4  \
# 9    15.0       63.0  80.0      89.5     15.0     17.0     22.0     13.0
# 17    NaN        NaN   NaN       NaN      NaN      NaN      NaN      NaN
# 41   20.0       70.0  85.0      93.7     15.0     22.0     19.0     10.0
# 79   20.0       70.0  75.0      87.7     23.0     23.0     24.0     20.0
# 88    5.0       23.0  60.0      56.8      5.0     12.0     12.0      4.0
#
#     Exam Total  Final Total
# 9         67.0        76.00
# 17         NaN          NaN
# ...

# %%
result.describe()
# Out:
#             S/No       Year         CA1      CA2-1      CA2-2  CA2 Total  \
# count  89.000000  89.000000   89.000000  89.000000  89.000000  89.000000
# mean   46.550562   1.449438   99.224719  31.505618   7.415730  38.921348
# std    26.913587   0.543792    4.689817   4.528003   2.141627   6.036301
# min     1.000000   1.000000   61.000000  19.000000   2.000000  23.000000
# 25%    24.000000   1.000000  100.000000  29.000000   6.000000  35.000000
# 50%    46.000000   1.000000  100.000000  32.000000   7.000000  39.000000
# 75%    70.000000   2.000000  100.000000  34.000000  10.000000  43.000000
# max    92.000000   3.000000  100.000000  40.000000  10.000000  50.000000
#
#            CA3-1      CA3-2      CA3-3  CA3 Total        CA4   CA Total  \
# count  89.000000  89.000000  89.000000  89.000000  89.000000  89.000000
# mean    7.247191  25.303371  13.146067  52.943820  71.269663  77.404382
# std     2.029783   6.176209   4.561575  12.336531   8.729214   9.470595
# ...

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 89 entries, 0 to 91
# Data columns (total 19 columns):
# S/No           89 non-null int32
# Year           89 non-null int32
# Nationality    89 non-null object
# CA1            89 non-null int32
# CA2-1          89 non-null int32
# CA2-2          89 non-null int32
# CA2 Total      89 non-null int32
# CA3-1          89 non-null float64
# CA3-2          89 non-null float64
# CA3-3          89 non-null float64
# CA3 Total      89 non-null float64
# CA4            89 non-null float64
# CA Total       89 non-null float64
# Exam Q1        89 non-null float64
# Exam Q2        89 non-null float64
# Exam Q3        89 non-null float64
# Exam Q4        89 non-null float64
# Exam Total     89 non-null float64
# Final Total    89 non-null float64
# dtypes: float64(12), int32(6), object(1)
# memory usage: 11.8+ KB

# %%
result.ix[17]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\Vu Anh Vinh\Miniconda3\envs\thkstat\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4154)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4018)()
#
# pandas\hashtable.pyx in pandas.hashtable.Int64HashTable.get_item (pandas\hashtable.c:6610)()
#
# pandas\hashtable.pyx in pandas.hashtable.Int64HashTable.get_item (pandas\hashtable.c:6554)()
#
# KeyError: 17
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-b23b5e9fc222> in <module>()
# ...

# %%
result.ix[18]
# Out:
# S/No              19
# Year               1
# Nationality    CONT1
# CA1               79
# CA2-1             30
# CA2-2              5
# CA2 Total         35
# CA3-1              7
# CA3-2             14
# CA3-3              9
# CA3 Total         37
# CA4               80
# CA Total       68.76
# Exam Q1           10
# Exam Q2           10
# Exam Q3           13
# Exam Q4            3
# Exam Total        36
# Final Total     49.1
# Name: 18, dtype: object

# %%
result[result['S/NO'] == 18]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\Vu Anh Vinh\Miniconda3\envs\thkstat\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4154)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4018)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12368)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12322)()
#
# KeyError: 'S/NO'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-73-c18b026e45c2> in <module>()
# ...

# %%
result[result['S/No'] == 18]
# Out:
# Empty DataFrame
# Columns: [S/No, Year, Nationality, CA1, CA2-1, CA2-2, CA2 Total, CA3-1, CA3-2, CA3-3, CA3 Total, CA4, CA Total, Exam Q1, Exam Q2, Exam Q3, Exam Q4, Exam Total, Final Total]
# Index: []

# %%
result[result['S/No'] == 17]
# Out:
#     S/No  Year Nationality  CA1  CA2-1  CA2-2  CA2 Total  CA3-1  CA3-2  CA3-3  \
# 16    17     2       CONT3  100     32      7         39    5.0   30.0   15.0
#
#     CA3 Total   CA4  CA Total  Exam Q1  Exam Q2  Exam Q3  Exam Q4  Exam Total  \
# 16       55.0  72.0     78.57     15.0     18.0     16.0     12.0        61.0
#
#     Final Total
# 16        68.03

# %%
result.ix[18]
# Out:
# S/No              19
# Year               1
# Nationality    CONT1
# CA1               79
# CA2-1             30
# CA2-2              5
# CA2 Total         35
# CA3-1              7
# CA3-2             14
# CA3-3              9
# CA3 Total         37
# CA4               80
# CA Total       68.76
# Exam Q1           10
# Exam Q2           10
# Exam Q3           13
# Exam Q4            3
# Exam Total        36
# Final Total     49.1
# Name: 18, dtype: object

# %%
result.ix[17]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\Vu Anh Vinh\Miniconda3\envs\thkstat\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4154)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4018)()
#
# pandas\hashtable.pyx in pandas.hashtable.Int64HashTable.get_item (pandas\hashtable.c:6610)()
#
# pandas\hashtable.pyx in pandas.hashtable.Int64HashTable.get_item (pandas\hashtable.c:6554)()
#
# KeyError: 17
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-b23b5e9fc222> in <module>()
# ...
